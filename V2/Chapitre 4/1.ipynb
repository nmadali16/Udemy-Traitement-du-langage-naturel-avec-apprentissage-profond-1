# %% [markdown]
# # Word2Vec with Negative Sampling Implementation
#
# In this Jupyter notebook, we will implement the Word2Vec model using the technique of **negative sampling**. Word2Vec is a popular algorithm for learning word representations (embeddings) from large text corpora. Negative sampling is an optimization technique used to efficiently train the model by approximating the softmax function with a binary classification task.
#
# We will go through the process of:
#
# 1. Preparing the text data for training.
# 2. Implementing the negative sampling objective function.
# 3. Training the Word2Vec model.
# 4. Evaluating the learned word embeddings.
#
# Let's get started with building the model!

# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-3.2.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.11)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.27.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2024.12.14)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading datasets-3.2.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 30.1 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 12.1 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 20.0 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 16.5 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 21.2 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed datasets-3.2.0 dill-0.3.8 fsspec-2024.9.0 multiprocess-0.70.16 xxhash-3.5.0

# %%
import datasets

train_data, test_data = datasets.load_dataset("imdb", split=["train", "test"])
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/7.81k [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/21.0M [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/20.5M [00:00<?, ?B/s]
# unsupervised-00000-of-00001.parquet:   0%|          | 0.00/42.0M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Generating unsupervised split:   0%|          | 0/50000 [00:00<?, ? examples/s]

# %%
train_text=[sample['text'] for sample in train_data][:2]

# %%
train_tokens=[ token for text in train_text for token in text.lower().split()]

# %%
from collections import Counter
vocab=Counter(train_tokens)
w2i={k:i for i, (k,v) in enumerate(vocab.items())}
i2w={v:k for   (k,v) in  w2i.items()}

# %%
print(len(w2i))
# Out:
# 309

# %% [markdown]
# To train Word2Vec with negative sampling, the formula for the objective function involves maximizing the likelihood of the context words while minimizing the likelihood of randomly sampled negative words. Here's the formula for training Word2Vec with negative sampling:
#
# ### Objective Function for Word2Vec with Negative Sampling
#
# Given a target word $w_t $ and a context word $w_c $, the objective is to maximize the probability of the context word given the target word using a logistic regression model. The model outputs a probability for the pair of words to be a valid context-target pair.
#
# 1. **Positive Pairs (True Context)**
#    The probability of a valid context word $w_c $ given the target word $w_t $ is:
#
#   $$
#    P(w_c | w_t) = \sigma(v_{w_c}^T v_{w_t})
#    $$
#
#    Where:
#    - $\sigma(x) $ is the sigmoid function, $\sigma(x) = \frac{1}{1 + e^{-x}} $,
#    - $v_{w_c} $ is the vector representation of the context word $w_c $,
#    - $v_{w_t} $ is the vector representation of the target word $w_t $.

# %%
import torch
import torch.nn as nn

u_o=nn.Embedding(len(w2i),300)
u_c=nn.Embedding(len(w2i),300)

# %% [markdown]
# 2. **Negative Sampling**
#    Negative sampling introduces random negative samples $w_n $ to train the model to distinguish valid word pairs from random noise. For each positive word pair $(w_t, w_c) $, we sample $k $ negative samples $w_n $. The objective function also includes the probability of the context word $w_n $ being sampled:
#
#   $$
#    P(w_n | w_t) = \sigma(-v_{w_n}^T v_{w_t})
#    $$
#
#    The negative sign is used to push the model to reduce the similarity between negative samples and the target word.

# %%
import nltk
import numpy as np

window_size=3
num_sample=5
for text in train_text:
  tokens=text.lower().split()
  for window in nltk.ngrams(tokens, window_size):
    central_word=window[window_size//2]
    context_words=[]
    for i in range(window_size):
      if i!=window_size//2:
        context_word=window[i]
        context_words.append(context_word)
        #print()
    prob=np.ones(len(w2i))
    for word in context_words:
      prob[w2i[word]]=0
    for context_word in context_words:
      print('Positive Sample ', (context_word, central_word ))
      negative_idxs=np.random.choice(len(w2i),size=num_sample, replace=False, p=prob/np.sum(prob))
      print('Negative sample :', [i2w[idx] for idx in negative_idxs])
  break
# Out:
# Positive Sample  ('i', 'rented')
# Negative sample : ['is', 'shock', 'less', 'porno.', "i've"]
# Positive Sample  ('i', 'rented')
# Negative sample : ['men.<br', '/>i', 'obvious', 'pile.', 'purposes']
# Positive Sample  ('rented', 'i')
# Negative sample : ['first', 'appears', 'then', 'come', 'u.s.']
# Positive Sample  ('am', 'i')
# Negative sample : ['life.', 'explicit', 'first', "it's", 'hardly']
# Positive Sample  ('i', 'am')
# Negative sample : ['in', 'even', 'anything', 'really,', 'attentions']
# Positive Sample  ('curious-yellow', 'am')
# Negative sample : ["don't", 'mentally', 'porn', 'am', 'reality']
# Positive Sample  ('am', 'curious-yellow')
# Negative sample : ['clitoris', 'culturally', 'asking', 'nude,', 'erotica.']
# Positive Sample  ('from', 'curious-yellow')
# Negative sample : ['treated', 'his', 'for', 'brown', 'making']
# Positive Sample  ('curious-yellow', 'from')
# Negative sample : ['from', 'wants', 'purposes', 'around', "we're"]
# Positive Sample  ('my', 'from')
# Negative sample : ['see', 'double', 'throbbing', 'site', 'artistic']
# Positive Sample  ('from', 'my')
# Negative sample : ['curious:', 'porno.', 'john', 'vulvas', '/>the']
# Positive Sample  ('video', 'my')
# Negative sample : ['money', 'level.', 'labia?', 'just', 'appears']
# Positive Sample  ('my', 'video')
# Negative sample : ['by', 'issues', 'shows:', 'pornographic', 'nudity.']
# Positive Sample  ('store', 'video')
# Negative sample : ['automatic', 'claim', 'swede', 'hardly', 'nc-17,']
# Positive Sample  ('video', 'store')
# Negative sample : ['while', 'porno.', '"controversial"', "one's", 'few']
# Positive Sample  ('because', 'store')
# Negative sample : ['shock', 'on', 'pornographic.', 'obtuse', 'swede']
# Positive Sample  ('store', 'because')
# Negative sample : ['admittedly', 'explicit', 'nowhere,', 'or', 'implying)']
# Positive Sample  ('of', 'because')
# Negative sample : ['depressing', 'answer', 'she', 'money', 'to']
# Positive Sample  ('because', 'of')
# Negative sample : ['am', 'made', 'men', 'mentally', 'even']
# Positive Sample  ('all', 'of')
# Negative sample : ["isn't", 'a', 'to', 'gaping', 'who']
# Positive Sample  ('of', 'all')
# Negative sample : ['rented', 'married', 'an', 'vincent', 'do']
# Positive Sample  ('the', 'all')
# Negative sample : ['level.', 'johnson,', 'fact,', 'curious:', '/>i']
# Positive Sample  ('all', 'the')
# Negative sample : ['obvious', 'steaming', '40', 'nudity,', 'swede']
# Positive Sample  ('controversy', 'the')
# Negative sample : ['porno.', 'treated', 'terms', 'see', 'fact']
# Positive Sample  ('the', 'controversy')
# Negative sample : ['shown', 'women:', 'seriously', 'not', 'men']
# Positive Sample  ('that', 'controversy')
# Negative sample : ['breeze', 'commend', 'married', 'asking', 'johnson,']
# Positive Sample  ('controversy', 'that')
# Negative sample : ['automatic', 'pun', 'visible', 'terms', 'heard']
# Positive Sample  ('surrounded', 'that')
# Negative sample : ['pile.', 'standard', 'first', 'yellow"', 'unavoidably']
# Positive Sample  ('that', 'surrounded')
# Negative sample : ['which', 'those', 'vincent', 'surrounded', 'difference']
# Positive Sample  ('it', 'surrounded')
# Negative sample : ['wants', 'should', "we're", 'come', 'difference']
# Positive Sample  ('surrounded', 'it')
# Negative sample : ['race', 'see', 'classmates,', 'in', 'political']
# Positive Sample  ('when', 'it')
# Negative sample : ['and', 'student', 'with', 'like', 'because']
# Positive Sample  ('it', 'when')
# Negative sample : ['vincent', 'into', 'politicians', 'ford,', 'married']
# Positive Sample  ('it', 'when')
# Negative sample : ['good', 'then', 'you', "doesn't", 'war']
# Positive Sample  ('when', 'it')
# Negative sample : ['before', 'vietnam', '/>the', 'her', 'are']
# Positive Sample  ('was', 'it')
# Negative sample : ['bodies.', 'much', 'sevigny.', 'country,', 'ordinary']
# Positive Sample  ('it', 'was')
# Negative sample : ['ordinary', 'clitoris', 'politics,', '/>what', 'ever']
# Positive Sample  ('first', 'was')
# Negative sample : ['video', 'surrounded', 'the', "we're", 'was']
# Positive Sample  ('was', 'first')
# Negative sample : ['frontal', 'money', 'certain', 'indie', 'then']
# Positive Sample  ('released', 'first')
# Negative sample : ['i', 'pun', 'video', 'nowhere,', 'man.']
# Positive Sample  ('first', 'released')
# Negative sample : ['insides', 'said', 'risible', "don't", 'short']
# Positive Sample  ('in', 'released')
# Negative sample : ['man.', 'said', 'yellow"', 'swedish', 'people']
# Positive Sample  ('released', 'in')
# Negative sample : ['have', 'ago,', 'surrounded', 'level.', 'plot']
# Positive Sample  ('1967.', 'in')
# Negative sample : ['men.<br', 'obtuse', 'or', 'pornographic', 'has']
# Positive Sample  ('in', '1967.')
# Negative sample : ['actresses', 'pun', 'teacher,', 'swinging', "won't"]
# Positive Sample  ('i', '1967.')
# Negative sample : ['life.', 'staple', 'like', 'potatoes', 'between,']
# Positive Sample  ('1967.', 'i')
# Negative sample : ['ingmar', 'meat', 'few', 'documentary', 'shows:']
# Positive Sample  ('also', 'i')
# Negative sample : ['find', 'curious:', 'really,', 'chloe', 'should']
# Positive Sample  ('i', 'also')
# Negative sample : ['one', 'much', 'money', 'steaming', 'or']
# Positive Sample  ('heard', 'also')
# Negative sample : ['films.<br', 'goes', 'staple', 'artistic', 'account']
# Positive Sample  ('also', 'heard')
# Negative sample : ['average', 'same', 'nudity.', 'fact,', 'kills']
# Positive Sample  ('that', 'heard')
# Negative sample : ['not', 'breeze', "i've", 'porno.', 'matter']
# Positive Sample  ('heard', 'that')
# Negative sample : ['can', 'commend', 'that', 'curious-yellow', 'years']
# Positive Sample  ('at', 'that')
# Negative sample : ['bodies.', 'same', 'chloe', 'short', 'steaming']
# Positive Sample  ('that', 'at')
# Negative sample : ['hardly', 'plot.', 'mentally', 'of', 'my']
# Positive Sample  ('first', 'at')
# Negative sample : ["one's", 'do', 'at', 'female', 'average']
# Positive Sample  ('at', 'first')
# Negative sample : ['unavoidably', "i've", 'about', 'theaters', 'her']
# Positive Sample  ('it', 'first')
# Negative sample : ['was', 'implying)', 'answer', 'student', 'then']
# Positive Sample  ('first', 'it')
# Negative sample : ['it', 'made', 'being', 'years', 'teacher,']
# Positive Sample  ('was', 'it')
# Negative sample : ['crying', 'as', 'because', "doesn't", 'with']
# Positive Sample  ('it', 'was')
# Negative sample : ['that', 'shot', 'really,', 'clitoris', 'am']
# Positive Sample  ('seized', 'was')
# Negative sample : ['store', "one's", 'making', 'everything', 'am']
# Positive Sample  ('was', 'seized')
# Negative sample : ['you', 'site', 'old', 'meat', 'race']
# Positive Sample  ('by', 'seized')
# Negative sample : ['brown', 'his', 'such', 'actresses', 'porn']
# Positive Sample  ('seized', 'by')
# Negative sample : ['depressing', 'between', 'few', 'treated', 'tried']
# Positive Sample  ('u.s.', 'by')
# Negative sample : ['video', 'exist.', 'display', 'bergman,', 'really,']
# Positive Sample  ('by', 'u.s.')
# Negative sample : ['between', 'years', 'stockholm', 'young', 'pornographic']
# Positive Sample  ('customs', 'u.s.')
# Negative sample : ['around', 'views,', 'flapping', 'she', 'breeze']
# Positive Sample  ('u.s.', 'customs')
# Negative sample : ['"double-standard"', 'anything', 'released', 'steaming', '/><br']
# Positive Sample  ('if', 'customs')
# Negative sample : ['has', 'appears', 'then', 'teacher,', 'throbbing']
# Positive Sample  ('customs', 'if')
# Negative sample : ['people', 'shock', 'their', 'make', 'erotica.']
# Positive Sample  ('it', 'if')
# Negative sample : ['also', 'visible', 'fact,', 'frontal', 'by']
# Positive Sample  ('if', 'it')
# Negative sample : ['boy', 'display', '(or', 'double-standard', 'nc-17,']
# Positive Sample  ('ever', 'it')
# Negative sample : ['gaping', 'not', '1967.', '(no', 'country,']
# Positive Sample  ('it', 'ever')
# Negative sample : ['(no', 'heard', 'pun', "i've", 'pornographic']
# Positive Sample  ('tried', 'ever')
# Negative sample : ['double-standard', 'by', '/>i', 'treated', 'shock']
# Positive Sample  ('ever', 'tried')
# Negative sample : ['with', 'money', 'be', 'being', 'their']
# Positive Sample  ('to', 'tried')
# Negative sample : ['bodies.', 'r-rated', 'cable', 'then', 'account']
# Positive Sample  ('tried', 'to')
# Negative sample : ['u.s.', 'is', 'meat', 'vulvas', 'documentary']
# Positive Sample  ('enter', 'to')
# Negative sample : ['1967.', 'her', 'surrounded', 'artistic', 'johnson,']
# Positive Sample  ('to', 'enter')
# Negative sample : ['his', 'nowhere,', 'unavoidably', 'yellow"', '/><br']
# Positive Sample  ('this', 'enter')
# Negative sample : ['ordinary', 'come', 'women:', 'her', 'considered']
# Positive Sample  ('enter', 'this')
# Negative sample : ['those', 'crappy', 'named', 'less', 'such']
# Positive Sample  ('country,', 'this')
# Negative sample : ['shown', 'come', 'nude,', "women's", 'clitoris']
# Positive Sample  ('this', 'country,')
# Negative sample : ['obtuse', 'culturally', 'difference', 'myself.<br', '1967.']
# Positive Sample  ('therefore', 'country,')
# Negative sample : ['man.', 'men', "don't", 'account', 'site']
# Positive Sample  ('country,', 'therefore')
# Negative sample : ['/><br', 'men.<br', 'boy', 'take', 'pornographic.']
# Positive Sample  ('being', 'therefore')
# Negative sample : ['an', 'focus', 'intended)', 'surrounded', 'one']
# Positive Sample  ('therefore', 'being')
# Negative sample : ['granted,', 'matters', 'actresses', 'johnson,', 'nowhere,']
# Positive Sample  ('a', 'being')
# Negative sample : ['by', 'to', 'lena', 'swede', 'unavoidably']
# Positive Sample  ('being', 'a')
# Negative sample : ['frontal', 'porn', 'female', 'do', 'goes']
# Positive Sample  ('fan', 'a')
# Negative sample : ['offer', 'explicit', 'wants', 'teacher,', 'making']
# Positive Sample  ('a', 'fan')
# Negative sample : ['crappy', 'obtuse', 'shows:', 'major', 'ability']
# Positive Sample  ('of', 'fan')
# Negative sample : ['u.s.', 'double-standard', 'because', 'trace', 'curious-yellow']
# Positive Sample  ('fan', 'of')
# Negative sample : ['like', 'appears', 'boy', 'being', 'plot']
# Positive Sample  ('films', 'of')
# Negative sample : ['curious-yellow', 'because', 'in', 'vulvas', 'commend']
# Positive Sample  ('of', 'films')
# Negative sample : ['that', 'any', 'ordinary', 'be', 'ago,']
# Positive Sample  ('considered', 'films')
# Negative sample : ['men', 'average', 'good', 'she', 'same']
# Positive Sample  ('films', 'considered')
# Negative sample : ['"double-standard"', 'major', 'porn', 'man.', 'same']
# Positive Sample  ('"controversial"', 'considered')
# Negative sample : ['chloe', 'genitals', 'a', 'old', 'anatomical']
# Positive Sample  ('considered', '"controversial"')
# Negative sample : ['scenes', 'purposes', 'lena', 'do', 'because']
# Positive Sample  ('i', '"controversial"')
# Negative sample : ['and', 'men', 'views', 'are', 'an']
# Positive Sample  ('"controversial"', 'i')
# Negative sample : ['matters', 'pretentious', 'just', 'america.', 'pink']
# Positive Sample  ('really', 'i')
# Negative sample : ['but', 'pink', 'sight.', 'video', 'trace']
# Positive Sample  ('i', 'really')
# Negative sample : ['wanting', "one's", 'such', 'see', 'thought']
# Positive Sample  ('had', 'really')
# Negative sample : ['(or', 'their', 'plot.', 'goes', 'major']
# Positive Sample  ('really', 'had')
# Negative sample : ['considered', 'just', 'john', 'shocking,', 'nudity,']
# Positive Sample  ('to', 'had')
# Negative sample : ['granted,', 'pile.', 'erotica.', 'nude,', 'matters']
# Positive Sample  ('had', 'to')
# Negative sample : ['where', 'you', 'is', 'everything', 'u.s.']
# Positive Sample  ('see', 'to')
# Negative sample : ['rather', 'plot.', 'mentally', 'sort', "won't"]
# Positive Sample  ('to', 'see')
# Negative sample : ['john', 'wanting', 'actresses', 'those', 'display']
# Positive Sample  ('this', 'see')
# Negative sample : ['really,', 'average', 'asking', 'swede', 'labia?']
# Positive Sample  ('see', 'this')
# Negative sample : ['less', 'between,', 'find', 'labia?', 'states.']
# Positive Sample  ('for', 'this')
# Negative sample : ['actresses', 'seized', 'sex', 'obvious', 'nudity']
# Positive Sample  ('this', 'for')
# Negative sample : ['arguably', 'clitoris', 'classmates,', 'also', 'particular']
# Positive Sample  ('myself.<br', 'for')
# Negative sample : ['not', 'shows:', 'married', 'account', 'ordinary']
# Positive Sample  ('for', 'myself.<br')
# Negative sample : ['anyone', "we're", 'swedish', "doesn't", 'r-rated']
# Positive Sample  ('/><br', 'myself.<br')
# Negative sample : ['people', 'with', 'wants', 'boy', 'arguably']
# Positive Sample  ('myself.<br', '/><br')
# Negative sample : ['purposes', 'site', "doesn't", 'young', 'indie']
# Positive Sample  ('/>the', '/><br')
# Negative sample : ['obvious', 'vulvas', 'seriously', 'pile.', 'has']
# Positive Sample  ('/><br', '/>the')
# Negative sample : ['their', 'war', 'vietnam', 'fact,', 'ingmar']
# Positive Sample  ('plot', '/>the')
# Negative sample : ['good', 'genitals', 'women:', 'cinema.', 'u.s.']
# Positive Sample  ('/>the', 'plot')
# Negative sample : ['this', 'unavoidably', 'anything', 'cinema.', 'fleeting']
# Positive Sample  ('is', 'plot')
# Negative sample : ['tried', '/><br', 'ingmar', 'they', 'throbbing']
# Positive Sample  ('plot', 'is')
# Negative sample : ['treated', 'at', 'frontal', 'it', 'shows:']
# Positive Sample  ('centered', 'is')
# Negative sample : ['to', 'into', 'bunny,', 'you', 'tried']
# Positive Sample  ('is', 'centered')
# Negative sample : ['/>what', 'they', 'granted,', 'issues', 'when']
# Positive Sample  ('around', 'centered')
# Negative sample : ['clitoris', 'far', 'named', 'where', 'money']
# Positive Sample  ('centered', 'around')
# Negative sample : ['by', 'porno.', 'gaping', 'the', 'thought']
# Positive Sample  ('a', 'around')
# Negative sample : ['curious-yellow', 'enter', 'has', 'this', 'shock']
# Positive Sample  ('around', 'a')
# Negative sample : ['cinema.', 'wanting', 'purposes', '(or', 'artistic']
# Positive Sample  ('young', 'a')
# Negative sample : ['come', 'is', 'or', 'about', 'throbbing']
# Positive Sample  ('a', 'young')
# Negative sample : ['r-rated', 'thought', 'nudity.', 'made', 'in']
# Positive Sample  ('swedish', 'young')
# Negative sample : ['porno.', 'throbbing', 'fact,', 'taken', 'that']
# Positive Sample  ('young', 'swedish')
# Negative sample : ['teacher,', 'tried', 'attentions', 'trace', 'appears']
# Positive Sample  ('drama', 'swedish')
# Negative sample : ['money', 'have', 'had', 'is', 'culturally']
# Positive Sample  ('swedish', 'drama')
# Negative sample : ['vietnam', '(no', 'mentally', 'study', 'can']
# Positive Sample  ('student', 'drama')
# Negative sample : ['should', 'cable', 'pun', 'swinging', 'arguably']
# Positive Sample  ('drama', 'student')
# Negative sample : ['nudity,', 'unavoidably', 'surrounded', 'brown', 'particular']
# Positive Sample  ('named', 'student')
# Negative sample : ['insides', 'cable', '1967.', 'nowhere,', 'states.']
# Positive Sample  ('student', 'named')
# Negative sample : ['shot', 'heard', 'cinema.', 'find', 'standard']
# Positive Sample  ('lena', 'named')
# Negative sample : ['matter', 'offer', 'views,', 'married', 'steaming']
# Positive Sample  ('named', 'lena')
# Negative sample : ['years', 'average', 'vietnam', 'flapping', 'they']
# Positive Sample  ('who', 'lena')
# Negative sample : ['countrymen', 'than', 'throbbing', 'intended)', 'curious-yellow']
# Positive Sample  ('lena', 'who')
# Negative sample : ['what', 'clitoris', 'display', 'drama', 'making']
# Positive Sample  ('wants', 'who')
# Negative sample : ['student', 'like', '/>i', 'artistic', 'be']
# Positive Sample  ('who', 'wants')
# Negative sample : ['america.', 'attentions', 'come', 'any', 'the']
# Positive Sample  ('to', 'wants')
# Negative sample : ["i've", 'flapping', 'those', 'also', 'good']
# Positive Sample  ('wants', 'to')
# Negative sample : ['ford,', 'claim', 'shocking,', 'treated', 'really']
# Positive Sample  ('learn', 'to')
# Negative sample : ['vincent', 'nc-17,', 'therefore', 'swinging', 'granted,']
# Positive Sample  ('to', 'learn')
# Negative sample : ['kills', "it's", 'made', 'about', 'fan']
# Positive Sample  ('everything', 'learn')
# Negative sample : ['depressing', 'less', 'rented', 'steaming', 'alleged']
# Positive Sample  ('learn', 'everything')
# Negative sample : ['major', 'all', 'even', 'kills', 'if']
# Positive Sample  ('she', 'everything')
# Negative sample : ['curious:', 'when', 'cable', 'said', 'certain']
# Positive Sample  ('everything', 'she')
# Negative sample : ['major', 'released', 'particular', 'fan', 'and']
# Positive Sample  ('can', 'she')
# Negative sample : ['indie', 'visible', 'pornographic.', 'rented', 'brown']
# Positive Sample  ('she', 'can')
# Negative sample : ['because', 'cheaply', 'i', 'with', 'labia?']
# Positive Sample  ('about', 'can')
# Negative sample : ['only', 'enter', "women's", '/><br', 'do']
# Positive Sample  ('can', 'about')
# Negative sample : ['controversy', 'which', 'nc-17,', 'if', "it's"]
# Positive Sample  ('life.', 'about')
# Negative sample : ['ford,', '"i', 'and', 'between', 'unavoidably']
# Positive Sample  ('about', 'life.')
# Negative sample : ['admittedly', 'rented', 'nudity', 'staple', "doesn't"]
# Positive Sample  ('in', 'life.')
# Negative sample : ['people', 'her', 'reality', 'drama', 'country,']
# Positive Sample  ('life.', 'in')
# Negative sample : ['old', 'schlongs', 'pornographic', 'short', 'matters']
# Positive Sample  ('particular', 'in')
# Negative sample : ["we're", 'teacher,', 'theaters', 'country,', 'bergman,']
# Positive Sample  ('in', 'particular')
# Negative sample : ['a', 'account', 'some', 'on', 'political']
# Positive Sample  ('she', 'particular')
# Negative sample : ['explicit', 'had', 'video', 'boy', '"i']
# Positive Sample  ('particular', 'she')
# Negative sample : ['tried', 'everything', 'steaming', 'it', 'myself.<br']
# Positive Sample  ('wants', 'she')
# Negative sample : ['life.', 'seized', 'she', 'goes', 'pornographic']
# Positive Sample  ('she', 'wants')
# Negative sample : ['boy', 'thought', 'said', 'erotica.', 'anything']
# Positive Sample  ('to', 'wants')
# Negative sample : ['u.s.', 'curious-yellow', 'find', 'display', 'store']
# Positive Sample  ('wants', 'to')
# Negative sample : ['between', 'they', 'sort', 'about', '"controversial"']
# Positive Sample  ('focus', 'to')
# Negative sample : ['states.', 'nc-17,', 'scenes', 'only', 'people']
# Positive Sample  ('to', 'focus')
# Negative sample : ['porn', '/><br', 'had', 'obtuse', 'scenes']
# Positive Sample  ('her', 'focus')
# Negative sample : ['those', 'come', 'before', '/><br', '(no']
# Positive Sample  ('focus', 'her')
# Negative sample : ['classmates,', 'it', 'nc-17,', 'frontal', 'her']
# Positive Sample  ('attentions', 'her')
# Negative sample : ['1967.', 'john', 'views,', 'had', 'politics,']
# Positive Sample  ('her', 'attentions')
# Negative sample : ['staple', 'a', 'like', 'john', 'can']
# Positive Sample  ('to', 'attentions')
# Negative sample : ['yellow"', 'ford,', 'study', 'porno.', 'pun']
# Positive Sample  ('attentions', 'to')
# Negative sample : ["one's", 'vulvas', '40', 'depressing', 'if']
# Positive Sample  ('making', 'to')
# Negative sample : ['on', 'good', 'pile.', 'implying)', 'shock']
# Positive Sample  ('to', 'making')
# Negative sample : ["don't", 'swinging', 'account', 'pretentious', 'wants']
# Positive Sample  ('some', 'making')
# Negative sample : ['staple', 'nowhere,', 'named', 'young', '1967.']
# Positive Sample  ('making', 'some')
# Negative sample : ['implying)', 'thought', 'fan', 'made', 'an']
# Positive Sample  ('sort', 'some')
# Negative sample : ['few', 'swede', 'cheaply', 'to', 'issues']
# Positive Sample  ('some', 'sort')
# Negative sample : ['while', 'for', 'teacher,', 'rather', 'when']
# Positive Sample  ('of', 'sort')
# Negative sample : ['her', 'brown', 'exist.', 'america.', 'terms']
# Positive Sample  ('sort', 'of')
# Negative sample : ['such', 'same', 'married', 'pun', 'or']
# Positive Sample  ('documentary', 'of')
# Negative sample : ['from', 'shot', 'can', "we're", 'united']
# Positive Sample  ('of', 'documentary')
# Negative sample : ['throbbing', 'major', 'vietnam', 'any', 'that']
# Positive Sample  ('on', 'documentary')
# Negative sample : ['all', 'films', '(or', 'nc-17,', 'women:']
# Positive Sample  ('documentary', 'on')
# Negative sample : ["i've", 'myself.<br', '(or', 'while', 'are']
# Positive Sample  ('what', 'on')
# Negative sample : ['women:', 'answer', 'being', 'issues', 'making']
# Positive Sample  ('on', 'what')
# Negative sample : ['denizens', 'race', 'sort', 'making', 'ability']
# Positive Sample  ('the', 'what')
# Negative sample : ['ford,', 'hardly', 'denizens', 'cable', 'to']
# Positive Sample  ('what', 'the')
# Negative sample : ['good', 'female', 'country,', 'no', "don't"]
# Positive Sample  ('average', 'the')
# Negative sample : ['this', 'people', 'female', 'also', 'standard']
# Positive Sample  ('the', 'average')
# Negative sample : ['risible', 'between', 'bodies.', 'named', 'treated']
# Positive Sample  ('swede', 'average')
# Negative sample : ['account', 'thought', 'also', 'rented', 'had']
# Positive Sample  ('average', 'swede')
# Negative sample : ['study', 'such', 'also', 'site', 'seized']
# Positive Sample  ('thought', 'swede')
# Negative sample : ['terms', 'filmmakers', 'to', "won't", 'teacher,']
# Positive Sample  ('swede', 'thought')
# Negative sample : ['films', '/>the', 'my', 'ago,', 'plot']
# Positive Sample  ('about', 'thought')
# Negative sample : ['countrymen', 'politics,', 'vietnam', 'trace', 'is']
# Positive Sample  ('thought', 'about')
# Negative sample : ['treated', 'display', 'released', '/><br', 'as']
# Positive Sample  ('certain', 'about')
# Negative sample : ['american', 'double-standard', 'plot', 'women:', 'shown']
# Positive Sample  ('about', 'certain')
# Negative sample : ['short', 'anatomical', 'wants', '/>what', 'fan']
# Positive Sample  ('political', 'certain')
# Negative sample : ['site', 'good', 'major', 'one', 'seen']
# Positive Sample  ('certain', 'political')
# Negative sample : ['steaming', 'u.s.', 'terms', 'money', 'drama']
# Positive Sample  ('issues', 'political')
# Negative sample : ['display', 'life.', 'commend', 'old', 'porn']
# Positive Sample  ('political', 'issues')
# Negative sample : ['issues', 'life.', 'nudity.', 'like', 'years']
# Positive Sample  ('such', 'issues')
# Negative sample : ['/><br', 'sevigny.', 'ever', '/>the', 'swedish']
# Positive Sample  ('issues', 'such')
# Negative sample : ['vulvas', 'myself.<br', 'his', 'man.', "isn't"]
# Positive Sample  ('as', 'such')
# Negative sample : ['filmmakers', 'have', "women's", 'politics,', 'terms']
# Positive Sample  ('such', 'as')
# Negative sample : ['pretentious', 'making', 'being', 'commend', 'theaters']
# Positive Sample  ('the', 'as')
# Negative sample : ['attentions', 'certain', 'there', 'schlongs', "one's"]
# Positive Sample  ('as', 'the')
# Negative sample : ['american', 'seriously', 'plot', 'curious:', 'seen']
# Positive Sample  ('vietnam', 'the')
# Negative sample : ['but', 'account', 'documentary', 'bunny,', 'the']
# Positive Sample  ('the', 'vietnam')
# Negative sample : ['appears', 'this', 'difference', 'see', 'theaters']
# Positive Sample  ('war', 'vietnam')
# Negative sample : ['true.', 'films.<br', 'controversy', 'admittedly', "it's"]
# Positive Sample  ('vietnam', 'war')
# Negative sample : ['theaters', 'wants', 'less', 'pretentious', 'while']
# Positive Sample  ('and', 'war')
# Negative sample : ['pretentious', 'all', 'my', 'countrymen', 'clitoris']
# Positive Sample  ('war', 'and')
# Negative sample : ['chloe', 'stockholm', 'from', 'any', 'ford,']
# Positive Sample  ('race', 'and')
# Negative sample : ['kills', 'goes', 'double', "women's", 'culturally']
# Positive Sample  ('and', 'race')
# Negative sample : ['wants', 'denizens', 'mind', 'while', 'stockholm']
# Positive Sample  ('issues', 'race')
# Negative sample : ['bunny,', 'between', 'video', 'breeze', 'nc-17,']
# Positive Sample  ('race', 'issues')
# Negative sample : ['yellow"', 'considered', 'heard', 'is', 'anyone']
# Positive Sample  ('in', 'issues')
# Negative sample : ['heard', 'schlongs', 'store', 'nudity.', 'first']
# Positive Sample  ('issues', 'in')
# Negative sample : ['throbbing', 'matter', 'if', 'learn', 'particular']
# Positive Sample  ('the', 'in')
# Negative sample : ['vietnam', 'from', 'insides', 'men', 'myself.<br']
# Positive Sample  ('in', 'the')
# Negative sample : ['implying)', 'fleeting', 'make', 'also', 'culturally']
# Positive Sample  ('united', 'the')
# Negative sample : ['views,', 'one', 'porn', 'boy', 'trace']
# Positive Sample  ('the', 'united')
# Negative sample : ['intended)', 'people', 'indie', 'matters', 'admittedly']
# Positive Sample  ('states.', 'united')
# Negative sample : ['customs', 'find', 'mind', "it's", 'far']
# Positive Sample  ('united', 'states.')
# Negative sample : ['pink', 'if', "isn't", 'actresses', 'frontal']
# Positive Sample  ('in', 'states.')
# Negative sample : ['or', 'goes', 'unavoidably', 'crappy', 'true.']
# Positive Sample  ('states.', 'in')
# Negative sample : ['obtuse', 'pun', 'asking', 'it', 'customs']
# Positive Sample  ('between', 'in')
# Negative sample : ['on', "doesn't", 'focus', 'just', 'into']
# Positive Sample  ('in', 'between')
# Negative sample : ['attentions', 'indie', 'male', '"controversial"', 'matter']
# Positive Sample  ('asking', 'between')
# Negative sample : ['plot', 'vincent', 'exist.', 'hardly', 'rather']
# Positive Sample  ('between', 'asking')
# Negative sample : ['much', 'offer', 'implying)', 'anyone', 'r-rated']
# Positive Sample  ('politicians', 'asking')
# Negative sample : ['seriously', 'my', 'porn', 'generally', 'political']
# Positive Sample  ('asking', 'politicians')
# Negative sample : ['take', 'by', 'kills', 'really,', 'treated']
# Positive Sample  ('and', 'politicians')
# Negative sample : ['around', 'r-rated', 'when', '"controversial"', "gallo's"]
# Positive Sample  ('politicians', 'and')
# Negative sample : ['centered', 'claim', 'sevigny.', 'nudity,', 'is']
# Positive Sample  ('ordinary', 'and')
# Negative sample : ['explicit', 'shocking,', 'automatic', 'seized', 'level.']
# Positive Sample  ('and', 'ordinary')
# Negative sample : ['shown', '1967.', 'schlongs', 'around', 'women:']
# Positive Sample  ('denizens', 'ordinary')
# Negative sample : ['considered', 'crappy', 'really,', 'plot.', 'certain']
# Positive Sample  ('ordinary', 'denizens')
# Negative sample : ['(or', 'swedish', 'vulvas', 'opinions', 'pink']
# Positive Sample  ('of', 'denizens')
# Negative sample : ['there', 'released', 'focus', 'has', 'depressing']
# Positive Sample  ('denizens', 'of')
# Negative sample : ['fan', '"i', 'pornographic', 'was', 'actresses']
# Positive Sample  ('stockholm', 'of')
# Negative sample : ['about', 'bodies.', 'men', 'life.', 'less']
# Positive Sample  ('of', 'stockholm')
# Negative sample : ["women's", 'nudity.', 'any', 'controversy', 'am']
# Positive Sample  ('about', 'stockholm')
# Negative sample : ['fan', 'arguably', 'men', 'site', 'women:']
# Positive Sample  ('stockholm', 'about')
# Negative sample : ['breeze', 'making', 'a', 'to', 'goes']
# Positive Sample  ('their', 'about')
# Negative sample : ['breeze', 'as', 'male', 'anatomical', 'everything']
# Positive Sample  ('about', 'their')
# Negative sample : ['tried', 'labia?', 'store', 'around', 'treated']
# Positive Sample  ('opinions', 'their')
# Negative sample : ['plot.', 'there', "gallo's", 'porn', 'trace']
# Positive Sample  ('their', 'opinions')
# Negative sample : ['vincent', 'thought', 'man.', 'pun', 'focus']
# Positive Sample  ('on', 'opinions')
# Negative sample : ['vietnam', '"controversial"', 'shocking,', 'cheaply', 'breeze']
# Positive Sample  ('opinions', 'on')
# Negative sample : ['lena', 'man.', 'major', 'even', 'learn']
# Positive Sample  ('politics,', 'on')
# Negative sample : ['sevigny.', '(or', 'scenes', 'curious:', 'because']
# Positive Sample  ('on', 'politics,')
# Negative sample : ['enter', 'swede', 'some', 'chloe', 'automatic']
# Positive Sample  ('she', 'politics,')
# Negative sample : ['at', 'sex', 'far', 'am', 'come']
# Positive Sample  ('politics,', 'she')
# Negative sample : ['matter', 'purposes', 'insides', 'john', "we're"]
# Positive Sample  ('has', 'she')
# Negative sample : ['controversy', '(or', 'even', 'porn', 'nudity.']
# Positive Sample  ('she', 'has')
# Negative sample : ['political', "women's", 'bunny,', 'people', 'politics,']
# Positive Sample  ('sex', 'has')
# Negative sample : ['one', 'fact,', 'lena', 'automatic', 'site']
# Positive Sample  ('has', 'sex')
# Negative sample : ['curious:', 'much', 'as', 'my', 'named']
# Positive Sample  ('with', 'sex')
# Negative sample : ['seriously', 'then', 'offer', 'not', 'at']
# Positive Sample  ('sex', 'with')
# Negative sample : ['then', 'artistic', 'reality', 'learn', 'united']
# Positive Sample  ('her', 'with')
# Negative sample : ['nude,', 'study', 'indie', 'not', 'nudity,']
# Positive Sample  ('with', 'her')
# Negative sample : ['people', 'customs', 'life.', 'women:', 'swede']
# Positive Sample  ('drama', 'her')
# Negative sample : ['major', 'denizens', 'cinema.', 'ingmar', 'pile.']
# Positive Sample  ('her', 'drama')
# Negative sample : ['schlongs', 'when', 'explicit', 'making', 'who']
# Positive Sample  ('teacher,', 'drama')
# Negative sample : ['be', 'fact', 'between', 'make', 'pun']
# Positive Sample  ('drama', 'teacher,')
# Negative sample : ['artistic', 'those', 'ford,', "gallo's", 'united']
# Positive Sample  ('classmates,', 'teacher,')
# Negative sample : ['vulvas', 'johnson,', 'ago,', 'issues', 'films.<br']
# Positive Sample  ('teacher,', 'classmates,')
# Negative sample : ['united', 'display', '"i', 'their', 'flapping']
# Positive Sample  ('and', 'classmates,')
# Negative sample : ['/><br', 'be', 'are', 'issues', 'vincent']
# Positive Sample  ('classmates,', 'and')
# Negative sample : ['which', 'therefore', 'any', 'less', 'breeze']
# Positive Sample  ('married', 'and')
# Negative sample : ['find', 'years', 'from', 'pornographic.', 'had']
# Positive Sample  ('and', 'married')
# Negative sample : ['films.<br', 'sevigny.', 'was', 'insides', 'good']
# Positive Sample  ('men.<br', 'married')
# Negative sample : ['actresses', 'rented', "we're", 'documentary', 'seen']
# Positive Sample  ('married', 'men.<br')
# Negative sample : ['difference', 'teacher,', 'have', 'depressing', 'what']
# Positive Sample  ('/><br', 'men.<br')
# Negative sample : ['(or', 'rather', 'be', 'curious-yellow', 'but']
# Positive Sample  ('men.<br', '/><br')
# Negative sample : ['where', 'politicians', 'display', 'artistic', 'breeze']
# Positive Sample  ('/>what', '/><br')
# Negative sample : ['curious-yellow', 'nc-17,', 'politicians', 'yellow"', 'fact,']
# Positive Sample  ('/><br', '/>what')
# Negative sample : ['america.', 'female', 'nudity,', 'indie', 'male']
# Positive Sample  ('kills', '/>what')
# Negative sample : ['far', 'teacher,', 'appears', 'anything', 'male']
# Positive Sample  ('/>what', 'kills')
# Negative sample : ['pile.', 'issues', 'porno.', 'flapping', 'wants']
# Positive Sample  ('me', 'kills')
# Negative sample : ['find', 'frontal', "women's", 'ordinary', 'movies']
# Positive Sample  ('kills', 'me')
# Negative sample : ['store', 'cable', 'thought', 'standard', 'being']
# Positive Sample  ('about', 'me')
# Negative sample : ['filmmakers', 'between,', 'cannot', 'bunny,', 'swedish']
# Positive Sample  ('me', 'about')
# Negative sample : ['answer', 'see', 'shot', 'american', 'porno.']
# Positive Sample  ('i', 'about')
# Negative sample : ['vincent', 'first', 'even', 'am', 'breeze']
# Positive Sample  ('about', 'i')
# Negative sample : ["won't", 'said', 'particular', 'breeze', 'views,']
# Positive Sample  ('am', 'i')
# Negative sample : ['between', 'those', 'do', 'she', 'ever']
# Positive Sample  ('i', 'am')
# Negative sample : ['life.', 'standard', 'fleeting', 'see', 'where']
# Positive Sample  ('curious-yellow', 'am')
# Negative sample : ['years', 'controversy', 'surrounded', 'obtuse', "gallo's"]
# Positive Sample  ('am', 'curious-yellow')
# Negative sample : ['explicit', 'automatic', 'me', "don't", 'between,']
# Positive Sample  ('is', 'curious-yellow')
# Negative sample : ['anatomical', 'only', 'if', 'married', 'before']
# Positive Sample  ('curious-yellow', 'is')
# Negative sample : ['account', 'even', 'attentions', 'matters', 'cinema.']
# Positive Sample  ('that', 'is')
# Negative sample : ['bunny,', 'considered', 'major', 'automatic', 'rented']
# Positive Sample  ('is', 'that')
# Negative sample : ['am', 'men.<br', 'swinging', 'opinions', 'account']
# Positive Sample  ('40', 'that')
# Negative sample : ['has', 'erotica.', 'swede', 'with', 'rented']
# Positive Sample  ('that', '40')
# Negative sample : ['alleged', 'are', 'difference', 'said', 'when']
# Positive Sample  ('years', '40')
# Negative sample : ['documentary', 'terms', 'fact,', 'has', 'united']
# Positive Sample  ('40', 'years')
# Negative sample : ['sight.', 'sex', 'actresses', 'make', 'offer']
# Positive Sample  ('ago,', 'years')
# Negative sample : ['pile.', 'answer', 'nc-17,', 'intended)', 'into']
# Positive Sample  ('years', 'ago,')
# Negative sample : ['rather', 'video', 'then', "i've", "doesn't"]
# Positive Sample  ('this', 'ago,')
# Negative sample : ['controversy', 'war', 'ago,', 'reality', 'do']
# Positive Sample  ('ago,', 'this')
# Negative sample : ['enter', 'asking', 'the', 'of', 'less']
# Positive Sample  ('was', 'this')
# Negative sample : ['pornographic', 'filmmakers', 'brown', 'reality', 'fact']
# Positive Sample  ('this', 'was')
# Negative sample : ['/><br', 'years', 'ago,', 'breeze', 'therefore']
# Positive Sample  ('considered', 'was')
# Negative sample : ['anything', 'it', "we're", 'come', 'such']
# Positive Sample  ('was', 'considered')
# Negative sample : ['unavoidably', 'really,', 'pile.', 'therefore', 'video']
# Positive Sample  ('pornographic.', 'considered')
# Negative sample : ['explicit', 'first', 'war', 'vulvas', 'same']
# Positive Sample  ('considered', 'pornographic.')
# Negative sample : ['video', 'meat', 'man.', 'vietnam', 'staple']
# Positive Sample  ('really,', 'pornographic.')
# Negative sample : ['same', 'vincent', 'or', 'when', 'swedish']
# Positive Sample  ('pornographic.', 'really,')
# Negative sample : ['frontal', 'everything', 'old', 'john', 'short']
# Positive Sample  ('the', 'really,')
# Negative sample : ['site', 'one', 'being', 'male', 'good']
# Positive Sample  ('really,', 'the')
# Negative sample : ['had', 'mentally', 'also', 'offer', 'major']
# Positive Sample  ('sex', 'the')
# Negative sample : ['a', 'ordinary', 'female', 'video', 'pink']
# Positive Sample  ('the', 'sex')
# Negative sample : ['seen', '/>the', 'films.<br', 'have', 'for']
# Positive Sample  ('and', 'sex')
# Negative sample : ['her', 'account', 'with', 'married', '"i']
# Positive Sample  ('sex', 'and')
# Negative sample : ['also', 'you', 'learn', 'female', 'matter']
# Positive Sample  ('nudity', 'and')
# Negative sample : ['vulvas', 'reality', 'while', 'swinging', 'shocking,']
# Positive Sample  ('and', 'nudity')
# Negative sample : ['unavoidably', 'this', 'one', 'take', 'find']
# Positive Sample  ('scenes', 'nudity')
# Negative sample : ['wants', 'life.', '"i', 'politicians', 'being']
# Positive Sample  ('nudity', 'scenes')
# Negative sample : ['the', 'commend', 'about', 'curious:', 'heard']
# Positive Sample  ('are', 'scenes')
# Negative sample : ['depressing', 'there', 'considered', 'young', 'crappy']
# Positive Sample  ('scenes', 'are')
# Negative sample : ['she', 'but', 'sevigny.', 'sex', 'bodies.']
# Positive Sample  ('few', 'are')
# Negative sample : ['only', 'female', 'my', 'admittedly', 'double']
# Positive Sample  ('are', 'few')
# Negative sample : ['short', 'around', 'nudity', 'reality', "we're"]
# Positive Sample  ('and', 'few')
# Negative sample : ['sex', "isn't", 'implying)', 'staple', '"double-standard"']
# Positive Sample  ('few', 'and')
# Negative sample : ['anatomical', 'filmmakers', 'video', 'film', 'her']
# Positive Sample  ('far', 'and')
# Negative sample : ['pun', '/>what', 'released', 'than', 'double-standard']
# Positive Sample  ('and', 'far')
# Negative sample : ['gaping', 'vulvas', 'risible', 'me', 'pink']
# Positive Sample  ('between,', 'far')
# Negative sample : ['controversy', 'surrounded', 'nudity,', 'men', 'pink']
# Positive Sample  ('far', 'between,')
# Negative sample : ['because', 'appears', 'while', 'opinions', 'only']
# Positive Sample  ('even', 'between,')
# Negative sample : ['enter', 'fact', 'should', 'shock', 'years']
# Positive Sample  ('between,', 'even')
# Negative sample : ['take', 'student', 'intended)', 'seriously', 'than']
# Positive Sample  ('then', 'even')
# Negative sample : ['old', 'good', 'schlongs', 'those', 'teacher,']
# Positive Sample  ('even', 'then')
# Negative sample : ['had', 'me', 'curious:', 'double-standard', '/>the']
# Positive Sample  ("it's", 'then')
# Negative sample : ['certain', 'life.', 'kills', "don't", 'thought']
# Positive Sample  ('then', "it's")
# Negative sample : ['fan', 'find', 'nude,', 'of', 'cinema.']
# Positive Sample  ('not', "it's")
# Negative sample : ['into', "we're", 'me', 'films', 'rather']
# Positive Sample  ("it's", 'not')
# Negative sample : ['standard', 'while', 'trace', 'denizens', "doesn't"]
# Positive Sample  ('shot', 'not')
# Negative sample : ["i've", 'controversy', 'cannot', 'flapping', '(or']
# Positive Sample  ('not', 'shot')
# Negative sample : ["one's", 'shocking,', 'such', 'unavoidably', 'political']
# Positive Sample  ('like', 'shot')
# Negative sample : ['her', 'swinging', 'bunny,', 'wants', 'pornographic']
# Positive Sample  ('shot', 'like')
# Negative sample : ['ago,', 'life.', 'throbbing', 'swinging', 'site']
# Positive Sample  ('some', 'like')
# Negative sample : ['also', 'average', 'actresses', 'an', 'johnson,']
# Positive Sample  ('like', 'some')
# Negative sample : ['video', 'chloe', '1967.', "doesn't", 'thought']
# Positive Sample  ('cheaply', 'some')
# Negative sample : ['in', "it's", 'yellow"', 'flapping', 'female']
# Positive Sample  ('some', 'cheaply')
# Negative sample : ['country,', 'released', 'old', 'crappy', 'potatoes']
# Positive Sample  ('made', 'cheaply')
# Negative sample : ['one', 'enter', 'only', 'meat', 'intended)']
# Positive Sample  ('cheaply', 'made')
# Negative sample : ['around', 'she', 'steaming', 'account', 'nowhere,']
# Positive Sample  ('porno.', 'made')
# Negative sample : ['display', '/>i', 'labia?', 'on', 'porn']
# Positive Sample  ('made', 'porno.')
# Negative sample : ['like', 'filmmakers', 'all', 'scenes', 'films']
# Positive Sample  ('while', 'porno.')
# Negative sample : ['admittedly', 'fact', 'any', 'anatomical', 'you']
# Positive Sample  ('porno.', 'while')
# Negative sample : ['said', 'had', 'because', 'was', 'obvious']
# Positive Sample  ('my', 'while')
# Negative sample : ['states.', 'surrounded', 'me', 'into', 'tried']
# Positive Sample  ('while', 'my')
# Negative sample : ['(no', 'treated', 'anything', 'shown', 'mentally']
# Positive Sample  ('countrymen', 'my')
# Negative sample : ['named', 'even', 'cannot', 'nudity.', 'enter']
# Positive Sample  ('my', 'countrymen')
# Negative sample : ['site', 'commend', 'bunny,', 'political', 'the']
# Positive Sample  ('mind', 'countrymen')
# Negative sample : ['"controversial"', 'indie', 'obtuse', 'all', 'automatic']
# Positive Sample  ('countrymen', 'mind')
# Negative sample : ['matters', 'hardly', 'states.', 'filmmakers', 'pornographic']
# Positive Sample  ('find', 'mind')
# Negative sample : ['film', 'risible', 'all', 'movies', 'shows:']
# Positive Sample  ('mind', 'find')
# Negative sample : ['cheaply', 'asking', "women's", 'should', 'pornographic.']
# Positive Sample  ('it', 'find')
# Negative sample : ['films.<br', "doesn't", 'anyone', 'everything', 'thought']
# Positive Sample  ('find', 'it')
# Negative sample : ['movies', 'his', 'see', 'seized', 'r-rated']
# Positive Sample  ('shocking,', 'it')
# Negative sample : ['(no', 'has', 'sort', 'named', 'be']
# Positive Sample  ('it', 'shocking,')
# Negative sample : ['by', 'their', '(no', 'sex', 'making']
# Positive Sample  ('in', 'shocking,')
# Negative sample : ['nude,', 'major', 'race', 'countrymen', 'sevigny.']
# Positive Sample  ('shocking,', 'in')
# Negative sample : ['display', 'made', 'are', 'matters', 'matter']
# Positive Sample  ('reality', 'in')
# Negative sample : ['fleeting', 'nudity', 'at', 'r-rated', 'treated']
# Positive Sample  ('in', 'reality')
# Negative sample : ['matters', 'r-rated', 'unavoidably', 'from', "it's"]
# Positive Sample  ('sex', 'reality')
# Negative sample : ['shocking,', 'as', 'views,', 'ever', 'film']
# Positive Sample  ('reality', 'sex')
# Negative sample : ['movies', 'ever', 'plot', 'come', 'labia?']
# Positive Sample  ('and', 'sex')
# Negative sample : ['making', 'bunny,', 'goes', 'ability', 'steaming']
# Positive Sample  ('sex', 'and')
# Negative sample : ['war', 'any', 'mind', 'country,', 'scenes']
# Positive Sample  ('nudity', 'and')
# Negative sample : ['labia?', 'women:', 'nowhere,', 'anyone', 'surrounded']
# Positive Sample  ('and', 'nudity')
# Negative sample : ['really', 'also', 'ability', 'shock', 'america.']
# Positive Sample  ('are', 'nudity')
# Negative sample : ['see', 'first', 'female', 'good', 'actresses']
# Positive Sample  ('nudity', 'are')
# Negative sample : ['because', 'really,', 'bunny,', 'about', 'is']
# Positive Sample  ('a', 'are')
# Negative sample : ['anyone', 'such', 'cannot', 'terms', 'no']
# Positive Sample  ('are', 'a')
# Negative sample : ['cannot', 'admittedly', 'shocking,', 'account', 'reality']
# Positive Sample  ('major', 'a')
# Negative sample : ["one's", '(or', 'terms', 'films', 'video']
# Positive Sample  ('a', 'major')
# Negative sample : ['hardly', 'alleged', 'bergman,', 'but', 'her']
# Positive Sample  ('staple', 'major')
# Negative sample : ['actresses', 'anatomical', '/>the', 'views,', 'it']
# Positive Sample  ('major', 'staple')
# Negative sample : ['treated', 'risible', 'offer', 'u.s.', 'find']
# Positive Sample  ('in', 'staple')
# Negative sample : ['am', 'clitoris', 'alleged', 'on', 'for']
# Positive Sample  ('staple', 'in')
# Negative sample : ['mind', 'plot', 'sort', 'seized', 'shown']
# Positive Sample  ('swedish', 'in')
# Negative sample : ['vulvas', 'tried', 'first', 'men', 'you']
# Positive Sample  ('in', 'swedish')
# Negative sample : ['matter', 'do', 'there', 'exist.', 'johnson,']
# Positive Sample  ('cinema.', 'swedish')
# Negative sample : ['everything', 'first', 'shock', 'some', 'named']
# Positive Sample  ('swedish', 'cinema.')
# Negative sample : ['which', 'man.', 'said', 'fact,', 'staple']
# Positive Sample  ('even', 'cinema.')
# Negative sample : ['then', 'by', 'breeze', 'ever', 'she']
# Positive Sample  ('cinema.', 'even')
# Negative sample : ['they', 'bergman,', 'seriously', 'had', 'wanting']
# Positive Sample  ('ingmar', 'even')
# Negative sample : ['pun', 'hardly', 'find', 'men.<br', 'while']
# Positive Sample  ('even', 'ingmar')
# Negative sample : ['treated', 'issues', 'pretentious', 'true.', 'alleged']
# Positive Sample  ('bergman,', 'ingmar')
# Negative sample : ['drama', 'particular', 'mentally', 'they', 'his']
# Positive Sample  ('ingmar', 'bergman,')
# Negative sample : ['is', 'exist.', 'ever', 'named', 'difference']
# Positive Sample  ('arguably', 'bergman,')
# Negative sample : ['films.<br', 'of', 'only', 'ford,', 'vulvas']
# Positive Sample  ('bergman,', 'arguably')
# Negative sample : ['male', 'risible', 'years', 'flapping', 'johnson,']
# Positive Sample  ('their', 'arguably')
# Negative sample : ['she', 'asking', 'shown', 'nudity.', 'indie']
# Positive Sample  ('arguably', 'their')
# Negative sample : ['40', 'boy', 'meat', 'shot', 'unavoidably']
# Positive Sample  ('answer', 'their')
# Negative sample : ['standard', 'same', 'myself.<br', 'an', 'than']
# Positive Sample  ('their', 'answer')
# Negative sample : ['as', 'john', 'also', 'pile.', 'race']
# Positive Sample  ('to', 'answer')
# Negative sample : ['pornographic', 'nude,', 'if', '"i', 'me']
# Positive Sample  ('answer', 'to')
# Negative sample : ['depressing', 'tried', 'around', 'bodies.', 'stockholm']
# Positive Sample  ('good', 'to')
# Negative sample : ['unavoidably', 'taken', 'student', 'one', 'matters']
# Positive Sample  ('to', 'good')
# Negative sample : ['also', 'on', 'they', 'pile.', 'appears']
# Positive Sample  ('old', 'good')
# Negative sample : ['young', 'myself.<br', 'breeze', 'admittedly', 'country,']
# Positive Sample  ('good', 'old')
# Negative sample : ['myself.<br', 'at', "women's", "gallo's", 'appears']
# Positive Sample  ('boy', 'old')
# Negative sample : ['swinging', 'staple', 'terms', 'erotica.', 'nude,']
# Positive Sample  ('old', 'boy')
# Negative sample : ['alleged', 'then', 'tried', 'kills', '(no']
# Positive Sample  ('john', 'boy')
# Negative sample : ['controversy', 'me', 'ingmar', 'attentions', 'man.']
# Positive Sample  ('boy', 'john')
# Negative sample : ['risible', 'enter', 'average', 'was', 'pink']
# Positive Sample  ('ford,', 'john')
# Negative sample : ['wanting', 'be', 'insides', 'any', 'fact']
# Positive Sample  ('john', 'ford,')
# Negative sample : ["gallo's", 'then', 'breeze', 'treated', 'rather']
# Positive Sample  ('had', 'ford,')
# Negative sample : ['reality', 'explicit', 'politics,', 'unavoidably', 'pun']
# Positive Sample  ('ford,', 'had')
# Negative sample : ['meat', 'difference', 'generally', 'first', 'and']
# Positive Sample  ('sex', 'had')
# Negative sample : ['such', 'staple', 'video', 'vietnam', '/><br']
# Positive Sample  ('had', 'sex')
# Negative sample : ['potatoes', 'nudity.', 'sex', '/>the', 'exist.']
# Positive Sample  ('scenes', 'sex')
# Negative sample : ['less', 'her', 'male', 'asking', 'ago,']
# Positive Sample  ('sex', 'scenes')
# Negative sample : ['the', 'classmates,', 'student', 'certain', 'fact,']
# Positive Sample  ('in', 'scenes')
# Negative sample : ['mentally', 'war', 'generally', 'meat', 'ever']
# Positive Sample  ('scenes', 'in')
# Negative sample : ['display', 'visible', 'said', 'nc-17,', 'me']
# Positive Sample  ('his', 'in')
# Negative sample : ['vulvas', 'standard', 'movies', 'political', 'such']
# Positive Sample  ('in', 'his')
# Negative sample : ['come', 'ability', '/><br', 'ford,', 'shown']
# Positive Sample  ('films.<br', 'his')
# Negative sample : ['fact', 'drama', 'sevigny.', 'they', 'short']
# Positive Sample  ('his', 'films.<br')
# Negative sample : ['reality', 'rather', 'that', 'you', 'arguably']
# Positive Sample  ('/><br', 'films.<br')
# Negative sample : ['obtuse', 'also', 'culturally', 'rented', 'few']
# Positive Sample  ('films.<br', '/><br')
# Negative sample : ['double', 'study', 'particular', 'bergman,', 'cannot']
# Positive Sample  ('/>i', '/><br')
# Negative sample : ['anything', 'his', 'average', 'risible', 'made']
# Positive Sample  ('/><br', '/>i')
# Negative sample : ['certain', 'making', 'schlongs', 'plot', 'account']
# Positive Sample  ('do', '/>i')
# Negative sample : ['political', 'cinema.', 'mentally', 'drama', 'as']
# Positive Sample  ('/>i', 'do')
# Negative sample : ['mentally', 'granted,', 'old', 'short', "women's"]
# Positive Sample  ('commend', 'do')
# Negative sample : ['then', 'intended)', 'asking', 'who', 'breeze']
# Positive Sample  ('do', 'commend')
# Negative sample : ['or', 'come', 'at', 'labia?', 'their']
# Positive Sample  ('the', 'commend')
# Negative sample : ["gallo's", 'some', 'life.', 'fact', 'shown']
# Positive Sample  ('commend', 'the')
# Negative sample : ['nudity,', 'see', 'ability', 'difference', 'tried']
# Positive Sample  ('filmmakers', 'the')
# Negative sample : ['documentary', 'politics,', 'culturally', 'men', 'trace']
# Positive Sample  ('the', 'filmmakers')
# Negative sample : ['good', 'from', 'pun', 'of', 'treated']
# Positive Sample  ('for', 'filmmakers')
# Negative sample : ['swedish', 'i', 'cable', '"double-standard"', 'rather']
# Positive Sample  ('filmmakers', 'for')
# Negative sample : ['taken', 'all', 'centered', 'films.<br', 'account']
# Positive Sample  ('the', 'for')
# Negative sample : ['curious:', 'released', 'swinging', 'r-rated', 'just']
# Positive Sample  ('for', 'the')
# Negative sample : ['arguably', 'who', 'rented', '/>i', 'particular']
# Positive Sample  ('fact', 'the')
# Negative sample : ['mentally', 'films.<br', 'wants', 'should', 'gaping']
# Positive Sample  ('the', 'fact')
# Negative sample : ['vulvas', 'myself.<br', 'films', 'before', 'i']
# Positive Sample  ('that', 'fact')
# Negative sample : ['pink', 'really,', 'claim', 'only', 'visible']
# Positive Sample  ('fact', 'that')
# Negative sample : ['said', 'movies', 'first', 'ability', 'of']
# Positive Sample  ('any', 'that')
# Negative sample : ['goes', 'granted,', 'sevigny.', 'seriously', 'married']
# Positive Sample  ('that', 'any')
# Negative sample : ['matter', 'theaters', "it's", 'kills', 'opinions']
# Positive Sample  ('sex', 'any')
# Negative sample : ['tried', 'male', 'vulvas', 'curious-yellow', 'student']
# Positive Sample  ('any', 'sex')
# Negative sample : ['answer', 'films.<br', 'wanting', 'can', 'enter']
# Positive Sample  ('shown', 'sex')
# Negative sample : ['(or', 'are', 'you', 'chloe', 'video']
# Positive Sample  ('sex', 'shown')
# Negative sample : ['when', 'throbbing', 'this', 'vincent', 'swedish']
# Positive Sample  ('in', 'shown')
# Negative sample : ['people', 'erotica.', 'countrymen', 'life.', 'site']
# Positive Sample  ('shown', 'in')
# Negative sample : ['teacher,', 'erotica.', 'who', 'really,', 'has']
# Positive Sample  ('the', 'in')
# Negative sample : ['fact,', 'pile.', 'meat', 'trace', 'everything']
# Positive Sample  ('in', 'the')
# Negative sample : ['brown', 'pornographic', 'as', 'obtuse', 'really']
# Positive Sample  ('film', 'the')
# Negative sample : ['shot', 'his', 'gaping', 'sort', 'nudity']
# Positive Sample  ('the', 'film')
# Negative sample : ['vulvas', 'their', 'or', 'bunny,', 'seized']
# Positive Sample  ('is', 'film')
# Negative sample : ['brown', 'have', 'breeze', 'good', 'people']
# Positive Sample  ('film', 'is')
# Negative sample : ['shot', 'into', "i've", 'pun', 'what']
# Positive Sample  ('shown', 'is')
# Negative sample : ['vietnam', 'as', 'rented', 'asking', 'john']
# Positive Sample  ('is', 'shown')
# Negative sample : ['drama', 'fact', 'to', 'brown', 'seen']
# Positive Sample  ('for', 'shown')
# Negative sample : ['years', 'are', 'female', 'trace', "it's"]
# Positive Sample  ('shown', 'for')
# Negative sample : ['rented', 'when', 'stockholm', 'student', 'that']
# Positive Sample  ('artistic', 'for')
# Negative sample : ['america.', 'first', 'shock', 'insides', '(or']
# Positive Sample  ('for', 'artistic')
# Negative sample : ['enter', 'film', 'answer', 'even', 'man.']
# Positive Sample  ('purposes', 'artistic')
# Negative sample : ['to', 'or', 'cable', '1967.', 'potatoes']
# Positive Sample  ('artistic', 'purposes')
# Negative sample : ['far', 'particular', 'thought', 'study', 'admittedly']
# Positive Sample  ('rather', 'purposes')
# Negative sample : ['actresses', 'trace', 'throbbing', 'as', 'particular']
# Positive Sample  ('purposes', 'rather')
# Negative sample : ['that', 'sex', 'major', 'answer', 'around']
# Positive Sample  ('than', 'rather')
# Negative sample : ['scenes', 'johnson,', 'indie', 'between,', 'not']
# Positive Sample  ('rather', 'than')
# Negative sample : ['standard', 'centered', 'potatoes', 'come', 'which']
# Positive Sample  ('just', 'than')
# Negative sample : ['making', 'implying)', 'his', 'nudity,', 'porno.']
# Positive Sample  ('than', 'just')
# Negative sample : ['controversy', 'money', 'wanting', 'crying', 'same']
# Positive Sample  ('to', 'just')
# Negative sample : ['thought', 'alleged', 'had', 'ago,', '/><br']
# Positive Sample  ('just', 'to')
# Negative sample : ['what', 'double-standard', 'american', 'swinging', 'ford,']
# Positive Sample  ('shock', 'to')
# Negative sample : ['brown', 'really', 'has', 'john', 'was']
# Positive Sample  ('to', 'shock')
# Negative sample : ['am', 'america.', 'crappy', 'fact,', 'site']
# Positive Sample  ('people', 'shock')
# Negative sample : ['also', 'anyone', "don't", 'pun', 'years']
# Positive Sample  ('shock', 'people')
# Negative sample : ['nudity.', 'who', 'between,', 'claim', 'young']
# Positive Sample  ('and', 'people')
# Negative sample : ['scenes', 'appears', 'answer', 'enter', 'insides']
# Positive Sample  ('people', 'and')
# Negative sample : ['frontal', 'said', 'treated', 'actresses', 'curious:']
# Positive Sample  ('make', 'and')
# Negative sample : ['one', "gallo's", '1967.', "don't", 'pretentious']
# Positive Sample  ('and', 'make')
# Negative sample : ['nc-17,', 'nudity', '"double-standard"', 'united', 'nowhere,']
# Positive Sample  ('money', 'make')
# Negative sample : ['standard', 'old', 'attentions', 'commend', 'women:']
# Positive Sample  ('make', 'money')
# Negative sample : ['see', 'pile.', 'offer', 'where', 'there']
# Positive Sample  ('to', 'money')
# Negative sample : ['money', 'nc-17,', 'store', 'between,', 'made']
# Positive Sample  ('money', 'to')
# Negative sample : ['meat', 'porn', 'first', 'political', 'attentions']
# Positive Sample  ('be', 'to')
# Negative sample : ['her', 'bodies.', 'see', 'certain', 'lena']
# Positive Sample  ('to', 'be')
# Negative sample : ['40', 'matter', 'tried', 'intended)', 'crappy']
# Positive Sample  ('shown', 'be')
# Negative sample : ['fact,', 'denizens', 'hardly', 'sevigny.', 'fan']
# Positive Sample  ('be', 'shown')
# Negative sample : ['rather', 'artistic', 'unavoidably', 'depressing', 'good']
# Positive Sample  ('in', 'shown')
# Negative sample : ['between,', 'on', 'man.', 'double-standard', 'yellow"']
# Positive Sample  ('shown', 'in')
# Negative sample : ['politics,', 'insides', 'level.', 'goes', 'pink']
# Positive Sample  ('pornographic', 'in')
# Negative sample : ['everything', 'if', 'all', 'taken', 'cinema.']
# Positive Sample  ('in', 'pornographic')
# Negative sample : ['country,', 'can', 'nudity,', 'what', 'curious-yellow']
# Positive Sample  ('theaters', 'pornographic')
# Negative sample : ['hardly', 'explicit', 'implying)', 'when', 'offer']
# Positive Sample  ('pornographic', 'theaters')
# Negative sample : ['wanting', 'come', '/>what', 'said', 'american']
# Positive Sample  ('in', 'theaters')
# Negative sample : ['less', 'terms', '"i', 'take', 'crying']
# Positive Sample  ('theaters', 'in')
# Negative sample : ['films.<br', 'that', "don't", 'site', 'curious-yellow']
# Positive Sample  ('america.', 'in')
# Negative sample : ['shock', 'cheaply', 'pretentious', 'as', 'no']
# Positive Sample  ('in', 'america.')
# Negative sample : ['by', 'female', 'certain', 'really,', 'rented']
# Positive Sample  ('i', 'america.')
# Negative sample : ['yellow"', 'flapping', 'curious-yellow', 'johnson,', '"double-standard"']
# Positive Sample  ('america.', 'i')
# Negative sample : ['asking', 'vincent', 'plot.', 'first', 'filmmakers']
# Positive Sample  ('am', 'i')
# Negative sample : ['denizens', 'like', 'pornographic.', 'shocking,', 'john']
# Positive Sample  ('i', 'am')
# Negative sample : ['much', 'far', '1967.', 'theaters', 'ever']
# Positive Sample  ('curious-yellow', 'am')
# Negative sample : ['genitals', 'risible', 'nowhere,', 'attentions', 'major']
# Positive Sample  ('am', 'curious-yellow')
# Negative sample : ['shows:', 'swedish', 'see', 'sight.', 'nudity.']
# Positive Sample  ('is', 'curious-yellow')
# Negative sample : ['pretentious', 'considered', 'good', 'named', 'yellow"']
# Positive Sample  ('curious-yellow', 'is')
# Negative sample : ["one's", 'reality', 'because', 'come', 'unavoidably']
# Positive Sample  ('a', 'is')
# Negative sample : ['surrounded', 'plot', 'between,', 'average', 'bergman,']
# Positive Sample  ('is', 'a')
# Negative sample : ['porn', 'documentary', 'genitals', 'standard', 'shock']
# Positive Sample  ('good', 'a')
# Negative sample : ['schlongs', 'culturally', 'chloe', 'porno.', 'explicit']
# Positive Sample  ('a', 'good')
# Negative sample : ['/>what', 'swinging', 'video', 'films', 'focus']
# Positive Sample  ('film', 'good')
# Negative sample : ['much', 'war', 'artistic', 'rather', 'at']
# Positive Sample  ('good', 'film')
# Negative sample : ["doesn't", 'everything', 'crappy', 'clitoris', 'wants']
# Positive Sample  ('for', 'film')
# Negative sample : ['swedish', "gallo's", "won't", 'her', 'mind']
# Positive Sample  ('film', 'for')
# Negative sample : ['really,', 'had', 'ford,', 'claim', 'young']
# Positive Sample  ('anyone', 'for')
# Negative sample : ['customs', 'pornographic.', 'fan', 'pile.', 'terms']
# Positive Sample  ('for', 'anyone')
# Negative sample : ['fan', 'female', 'exist.', 'tried', 'between,']
# Positive Sample  ('wanting', 'anyone')
# Negative sample : ['myself.<br', 'is', 'also', 'all', 'risible']
# Positive Sample  ('anyone', 'wanting')
# Negative sample : ['america.', 'into', 'come', 'myself.<br', 'gaping']
# Positive Sample  ('to', 'wanting')
# Negative sample : ['seen', 'mind', '"controversial"', 'tried', "isn't"]
# Positive Sample  ('wanting', 'to')
# Negative sample : ['make', 'steaming', 'money', 'major', '/>i']
# Positive Sample  ('study', 'to')
# Negative sample : ['erotica.', 'political', 'breeze', 'movies', 'nc-17,']
# Positive Sample  ('to', 'study')
# Negative sample : ["isn't", 'but', 'which', 'you', 'anatomical']
# Positive Sample  ('the', 'study')
# Negative sample : ['unavoidably', 'views,', 'curious-yellow', 'pile.', 'pink']
# Positive Sample  ('study', 'the')
# Negative sample : ['1967.', 'much', 'ford,', 'issues', 'wanting']
# Positive Sample  ('meat', 'the')
# Negative sample : ['/>what', "it's", 'much', 'automatic', 'race']
# Positive Sample  ('the', 'meat')
# Negative sample : ['labia?', 'being', 'first', 'shocking,', 'are']
# Positive Sample  ('and', 'meat')
# Negative sample : ['labia?', 'few', 'had', 'just', 'nudity.']
# Positive Sample  ('meat', 'and')
# Negative sample : ['throbbing', 'life.', "women's", 'with', 'views,']
# Positive Sample  ('potatoes', 'and')
# Negative sample : ['was', 'united', 'mind', 'not', 'johnson,']
# Positive Sample  ('and', 'potatoes')
# Negative sample : ['what', 'artistic', 'this', 'not', 'seriously']
# Positive Sample  ('(no', 'potatoes')
# Negative sample : ["won't", 'video', 'war', 'johnson,', 'depressing']
# Positive Sample  ('potatoes', '(no')
# Negative sample : ['of', 'made', 'war', 'obtuse', 'therefore']
# Positive Sample  ('pun', '(no')
# Negative sample : ['boy', 'cheaply', 'generally', 'life.', 'average']
# Positive Sample  ('(no', 'pun')
# Negative sample : ['denizens', 'difference', 'good', 'shot', 'reality']
# Positive Sample  ('intended)', 'pun')
# Negative sample : ['lena', 'john', 'that', 'trace', 'theaters']
# Positive Sample  ('pun', 'intended)')
# Negative sample : ['movies', 'i', 'nude,', 'boy', 'seriously']
# Positive Sample  ('of', 'intended)')
# Negative sample : ['myself.<br', 'short', 'terms', 'video', 'porno.']
# Positive Sample  ('intended)', 'of')
# Negative sample : ['automatic', 'arguably', 'classmates,', 'views', 'cannot']
# Positive Sample  ('swedish', 'of')
# Negative sample : ['any', 'not', 'politics,', 'politicians', 'was']
# Positive Sample  ('of', 'swedish')
# Negative sample : ['meat', 'level.', 'terms', 'granted,', 'and']
# Positive Sample  ('cinema.', 'swedish')
# Negative sample : ['rather', "it's", 'not', 'this', 'bunny,']
# Positive Sample  ('swedish', 'cinema.')
# Negative sample : ['before', 'risible', 'study', 'and', 'can']
# Positive Sample  ('but', 'cinema.')
# Negative sample : ['people', "women's", 'are', 'r-rated', 'female']
# Positive Sample  ('cinema.', 'but')
# Negative sample : ['this', 'everything', 'enter', "we're", 'attentions']
# Positive Sample  ('really,', 'but')
# Negative sample : ['race', 'about', 'double-standard', "it's", 'women:']
# Positive Sample  ('but', 'really,')
# Negative sample : ['should', 'exist.', '(no', 'ford,', 'u.s.']
# Positive Sample  ('this', 'really,')
# Negative sample : ['focus', 'terms', 'everything', 'by', 'standard']
# Positive Sample  ('really,', 'this')
# Negative sample : ['nc-17,', 'u.s.', 'the', 'centered', 'america.']
# Positive Sample  ('film', 'this')
# Negative sample : ['(or', "i've", 'gaping', "women's", 'artistic']
# Positive Sample  ('this', 'film')
# Negative sample : ['you', 'while', 'it', 'life.', 'johnson,']
# Positive Sample  ("doesn't", 'film')
# Negative sample : ['or', 'pile.', 'politicians', 'life.', 'take']
# Positive Sample  ('film', "doesn't")
# Negative sample : ['shown', 'gaping', 'american', 'swinging', 'between']
# Positive Sample  ('have', "doesn't")
# Negative sample : ['treated', 'site', 'mentally', "it's", 'swedish']
# Positive Sample  ("doesn't", 'have')
# Negative sample : ['this', 'fleeting', 'flapping', 'meat', 'if']
# Positive Sample  ('much', 'have')
# Negative sample : ['first', 'thought', 'she', 'r-rated', 'young']
# Positive Sample  ('have', 'much')
# Negative sample : ['political', 'john', 'such', 'unavoidably', 'drama']
# Positive Sample  ('of', 'much')
# Negative sample : ['visible', 'porno.', 'exist.', 'around', 'has']
# Positive Sample  ('much', 'of')
# Negative sample : ['which', 'plot', 'or', 'bergman,', 'hardly']
# Positive Sample  ('a', 'of')
# Negative sample : ['released', 'nowhere,', 'nude,', 'theaters', 'brown']
# Positive Sample  ('of', 'a')
# Negative sample : ['movies', 'it', 'hardly', 'are', "it's"]
# Positive Sample  ('plot.', 'a')
# Negative sample : ['obvious', 'just', 'or', 'and', 'can']

# %%
#For postive pair
torch.sigmoid(u_c(torch.tensor(w2i[central_word])).dot(u_o(torch.tensor(w2i[context_word]))))
# Out:
# tensor(1., grad_fn=<SigmoidBackward0>)

# %%
#For Negative pair
torch.sigmoid(-u_c(torch.tensor(w2i[central_word])).dot(u_o(torch.tensor(negative_idxs[0]))))
# Out:
# tensor(0.9540, grad_fn=<SigmoidBackward0>)

# %% [markdown]
# 3. **Final Objective Function**
#    The final objective function to maximize is:
#
#   $$
#    J(w_t, w_c) = \log \sigma(v_{w_c}^T v_{w_t}) + \sum_{n=1}^k \mathbb{E}_{w_n \sim P(w)} \left[ \log \sigma(-v_{w_n}^T v_{w_t}) \right]
#    $$
#
#    Where:
#    - The first term corresponds to the positive sample (context word),
#    - The second term sums over the negative samples, where each negative sample $w_n $ is drawn from a distribution $P(w) $ (often a unigram distribution raised to a power, e.g., $P(w) = \frac{p(w)^\alpha}{\sum_{w'} p(w')^\alpha} $).
#
# By maximizing this objective, the model learns to increase the similarity between the target word vector $v_{w_t} $ and the context word vectors $v_{w_c} $, while decreasing the similarity with negative samples.

# %%
import torch.optim as optim
optimizer=optim.Adam([u_o.weight, u_c.weight])

# %%
from tqdm import tqdm
window_size=3
num_sample=5
for text in train_text:
  tokens=text.lower().split()
  for window in tqdm(nltk.ngrams(tokens, window_size)):
    central_word=window[window_size//2]
    context_words=[]
    for i in range(window_size):
      if i!=window_size//2:
        context_word=window[i]
        context_words.append(context_word)

    prob=np.ones(len(w2i))
    for word in context_words:
      prob[w2i[word]]=0
    for context_word in context_words:
      optimizer.zero_grad()
      loss=torch.log(torch.sigmoid(u_c(torch.tensor(w2i[central_word])).dot(u_o(torch.tensor(w2i[context_word])))))
      negative_idxs=np.random.choice(len(w2i),size=num_sample, replace=False, p=prob/np.sum(prob))
      for negative_idx in negative_idxs:
          loss+=torch.log(torch.sigmoid(-u_c(torch.tensor(w2i[central_word])).dot(u_o(torch.tensor(negative_idx)))))
      loss.backward()
      optimizer.step()
# Out:
# 286it [00:01, 176.26it/s]
# 212it [00:01, 183.31it/s]

# %%
v=(u_o.weight.data.numpy()+u_c.weight.data.numpy())/2

# %%
v.shape
# Out:
# (309, 300)

# %% [markdown]
# # Importing Pretrained Word2Vec Using Gensim
#
# The Gensim library is a popular Python package for natural language processing tasks, particularly for working with word embeddings such as Word2Vec. Gensim provides a straightforward way to load pretrained Word2Vec models, including Google's pretrained Word2Vec model or others in the `.bin` or `.txt` format.
#
# Here’s a step-by-step guide to import a pretrained Word2Vec model:
#
# ## Steps to Import Pretrained Word2Vec
#
# 1. **Install Gensim**
#    If you haven't installed Gensim, you can install it using pip:
#    ```bash
#    pip install gensim
#    ```

# %% [markdown]
# 2. **Download a Pretrained Word2Vec Model**
#    Commonly used pretrained models include:
#    - Google's pretrained Word2Vec model: [Google News vectors](https://code.google.com/archive/p/word2vec/)
#    - Other links https://huggingface.co/fse/word2vec-google-news-300
#    - Other embeddings such as FastText, Glove, or models trained on specific datasets.

# %%
# !gdown --id 0B7XkCwpI5KDYNlNUTTlSS21pQmM
# Out:
# /usr/local/lib/python3.11/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=0B7XkCwpI5KDYNlNUTTlSS21pQmM
# From (redirected): https://drive.google.com/uc?id=0B7XkCwpI5KDYNlNUTTlSS21pQmM&confirm=t&uuid=77b49503-6403-4287-90f7-7098200cb12c
# To: /content/GoogleNews-vectors-negative300.bin.gz
# 100% 1.65G/1.65G [00:38<00:00, 43.1MB/s]

# %% [markdown]
# 3. **Load the Pretrained Model**
#    Use the `KeyedVectors` module from Gensim to load the pretrained model. If the model is in binary format, set `binary=True`. Otherwise, leave it as `binary=False`.
#
#    ```python
#    from gensim.models import KeyedVectors
#
#    # Path to the pretrained model
#    model_path = "path/to/pretrained/word2vec.bin"
#
#    # Load the model
#    word2vec_model = KeyedVectors.load_word2vec_format(model_path, binary=True)
#    ```

# %%
from gensim.models import KeyedVectors

# Path to the pretrained model
model_path = "GoogleNews-vectors-negative300.bin.gz"

# Load the model
word2vec_model = KeyedVectors.load_word2vec_format(model_path, binary=True)

# %% [markdown]
# 4. **Using the Loaded Model**
#    Once loaded, you can use the model to:
#    - Retrieve vector representation of words:
#      ```python
#      vector = word2vec_model["example"]
#      print(vector)
#      ```
#    - Find most similar words:
#      ```python
#      similar_words = word2vec_model.most_similar("king", topn=5)
#      print(similar_words)
#      ```
#    - Compute similarity between words:
#      ```python
#      similarity = word2vec_model.similarity("king", "queen")
#      print(similarity)
#      ```

# %%
vector = word2vec_model["example"]
print(vector.shape)
# Out:
# (300,)

# %%
similarity = word2vec_model.similarity("king", "queen")
print(similarity)
# Out:
# 0.6510956

# %%
word2vec_model["France"]
# Out:
# array([ 4.85839844e-02,  7.86132812e-02,  3.24218750e-01,  3.49121094e-02,
#         7.71484375e-02,  3.54003906e-02, -1.25976562e-01, -3.86718750e-01,
#        -1.31835938e-01,  2.91748047e-02, -1.44531250e-01, -1.42578125e-01,
#         1.79687500e-01, -2.75390625e-01, -1.65039062e-01,  9.32617188e-02,
#         1.17187500e-01,  1.82617188e-01,  6.10351562e-02,  1.14257812e-01,
#         1.82617188e-01, -1.16699219e-01, -3.24707031e-02, -7.56835938e-02,
#         9.64355469e-03,  8.59375000e-02, -2.85156250e-01, -2.55859375e-01,
#         3.01513672e-02,  2.16796875e-01, -1.00097656e-01,  2.85644531e-02,
#        -2.81250000e-01, -8.39843750e-02, -2.02636719e-02, -1.96289062e-01,
#        -4.78515625e-02,  7.12890625e-02, -1.42578125e-01, -1.13525391e-02,
#         1.16210938e-01,  7.22656250e-02,  1.47460938e-01,  1.50390625e-01,
#         1.40625000e-01,  2.47070312e-01, -1.69921875e-01,  7.76367188e-02,
#        -5.44433594e-02,  1.66992188e-01, -1.45507812e-01,  2.12402344e-02,
#        -7.51953125e-02,  4.58984375e-02, -2.55859375e-01,  1.49414062e-01,
#        -5.62500000e-01, -1.34765625e-01, -1.87500000e-01, -3.26538086e-03,
#         8.44726562e-02,  1.33789062e-01,  2.99072266e-02, -2.92968750e-01,
#        -1.56250000e-01,  2.50244141e-03, -1.10473633e-02, -7.08007812e-02,
#         1.90429688e-02,  1.56250000e-01, -4.95605469e-02,  2.08007812e-01,
#        -3.66210938e-02,  2.07031250e-01,  1.27929688e-01,  2.91748047e-02,
#        -4.88281250e-03, -6.31713867e-03,  6.49414062e-02,  1.66015625e-01,
#        -1.08032227e-02, -1.83593750e-01,  1.49414062e-01, -1.71875000e-01,
#         1.85546875e-01, -9.86328125e-02, -2.10937500e-01, -2.06298828e-02,
#         1.02050781e-01,  1.41601562e-01, -1.21093750e-01,  5.93261719e-02,
#        -2.89062500e-01,  7.47070312e-02,  3.11279297e-02, -2.21679688e-01,
#         1.94335938e-01, -4.62890625e-01, -6.78710938e-02, -1.91650391e-02,
#        -2.39257812e-01, -1.09863281e-01, -1.45507812e-01,  1.81640625e-01,
#         1.27929688e-01, -1.41601562e-01,  8.39843750e-02, -6.56127930e-03,
#         8.83789062e-02,  2.75878906e-02, -5.61523438e-03,  8.88671875e-02,
#         2.25585938e-01, -3.49121094e-02,  1.72851562e-01, -2.64892578e-02,
#         1.61743164e-03,  2.17773438e-01,  3.51562500e-01,  1.61132812e-01,
#        -8.20312500e-02, -1.36718750e-01,  2.20947266e-02, -2.96630859e-02,
#         2.77343750e-01, -1.67968750e-01, -3.08837891e-02, -1.59179688e-01,
#        -4.00390625e-01,  8.93554688e-02,  2.99072266e-02,  1.82617188e-01,
#        -3.06640625e-01, -1.74804688e-01, -9.09423828e-03, -4.51660156e-02,
#         4.34570312e-02, -1.25732422e-02,  1.57226562e-01, -7.66601562e-02,
#         2.36328125e-01, -1.10839844e-01,  2.11914062e-01, -5.29785156e-02,
#         1.22558594e-01,  9.39941406e-03,  1.25976562e-01,  4.85839844e-02,
#        -4.76074219e-02, -2.09960938e-01, -1.42578125e-01,  1.34277344e-02,
#        -3.35693359e-03,  8.39843750e-02,  1.03515625e-01, -3.14453125e-01,
#         8.48388672e-03,  1.78710938e-01,  9.47265625e-02,  1.61132812e-01,
#        -4.76074219e-02,  1.91406250e-01,  2.09960938e-01, -7.17773438e-02,
#         2.94921875e-01, -1.96289062e-01, -1.78710938e-01,  1.10351562e-01,
#        -1.77001953e-02,  9.66796875e-02, -1.20605469e-01,  1.40625000e-01,
#         6.34765625e-02, -1.93359375e-01, -7.27539062e-02, -6.64062500e-02,
#         4.46777344e-02, -1.25000000e-01,  1.26953125e-01, -1.02539062e-01,
#         1.30859375e-01, -2.37304688e-01, -3.10546875e-01, -2.39257812e-01,
#         4.23828125e-01, -3.55529785e-03,  1.85546875e-01,  2.38281250e-01,
#        -1.48437500e-01,  1.91406250e-01,  1.20117188e-01,  5.73730469e-02,
#         1.11816406e-01,  9.52148438e-03, -1.42822266e-02,  3.33984375e-01,
#         1.17675781e-01, -8.44726562e-02, -1.66992188e-01, -2.12890625e-01,
#         1.13281250e-01,  3.71093750e-02, -6.00585938e-02, -1.61132812e-01,
#         1.28906250e-01,  1.63085938e-01, -1.76757812e-01, -2.05078125e-01,
#         7.95898438e-02, -7.95898438e-02,  5.39550781e-02, -1.28906250e-01,
#        -8.64257812e-02,  3.75000000e-01, -1.26953125e-01, -1.11328125e-01,
#         1.81884766e-02, -1.55273438e-01,  1.50390625e-01, -4.27246094e-02,
#        -1.30859375e-01, -1.69921875e-01, -6.16455078e-03, -3.06396484e-02,
#        -1.56250000e-01,  7.37304688e-02,  2.59765625e-01,  8.49609375e-02,
#         3.71093750e-01,  9.22851562e-02, -9.81445312e-02, -3.39355469e-02,
#         2.01171875e-01,  7.12890625e-02, -5.49316406e-02,  3.61328125e-02,
#        -9.32617188e-02,  7.56835938e-02, -2.29492188e-01, -8.15429688e-02,
#         8.88671875e-02, -6.03027344e-02,  1.64062500e-01,  2.35351562e-01,
#         1.41601562e-01,  7.03125000e-02, -3.90625000e-01, -1.15722656e-01,
#        -2.25585938e-01, -1.12792969e-01,  8.59375000e-02,  7.81250000e-02,
#        -2.20947266e-02,  1.56250000e-01,  4.76074219e-02,  1.19140625e-01,
#         3.61328125e-02, -1.98242188e-01,  7.47070312e-02,  1.72851562e-01,
#         6.98242188e-02,  2.75390625e-01, -3.36914062e-02,  2.49023438e-01,
#         2.17773438e-01, -6.03027344e-02, -1.47460938e-01, -2.92968750e-01,
#        -1.18164062e-01,  1.43554688e-01, -1.95312500e-01,  7.56835938e-02,
#        -3.56445312e-02, -1.07910156e-01,  7.51953125e-02,  9.81445312e-02,
#        -6.59179688e-02,  2.65625000e-01, -1.48437500e-01,  4.93164062e-02,
#        -2.37304688e-01,  2.50244141e-02,  8.69750977e-04, -3.47900391e-03,
#        -8.25195312e-02,  2.43164062e-01, -2.49023438e-02,  1.49414062e-01,
#        -6.64062500e-02,  4.95605469e-02,  1.38671875e-01,  3.16406250e-01,
#        -6.58035278e-05,  1.62109375e-01, -1.54296875e-01, -7.71484375e-02,
#        -1.19628906e-01, -2.22167969e-02,  1.60156250e-01, -7.17773438e-02],
#       dtype=float32)

# %%
word2vec_model["frame"]
# Out:
# array([-2.57568359e-02,  3.57421875e-01, -3.08837891e-02,  8.25195312e-02,
#         9.96093750e-02, -1.64062500e-01,  4.80468750e-01, -5.51757812e-02,
#         2.27539062e-01, -1.03149414e-02,  4.12597656e-02,  6.25000000e-02,
#        -1.75781250e-01,  1.90734863e-03, -2.05078125e-02, -1.70898438e-01,
#         5.98144531e-03,  1.89453125e-01, -1.51977539e-02, -1.90429688e-01,
#        -9.81445312e-02, -2.95410156e-02, -1.00097656e-01, -1.18408203e-02,
#         4.08935547e-03, -5.00488281e-03, -3.02734375e-01,  1.38671875e-01,
#         1.27929688e-01,  3.12500000e-02, -1.25000000e-01,  1.52343750e-01,
#        -9.70458984e-03,  6.00585938e-02,  2.31933594e-02, -2.96875000e-01,
#        -1.79687500e-01,  3.73535156e-02, -1.15234375e-01,  2.77099609e-02,
#         2.96875000e-01,  8.39843750e-02,  1.65039062e-01,  6.93359375e-02,
#         2.03125000e-01,  3.11279297e-02, -1.05957031e-01,  1.99218750e-01,
#         1.96289062e-01,  1.64062500e-01,  3.68652344e-02, -2.22656250e-01,
#        -8.34960938e-02, -2.34375000e-01,  1.28906250e-01,  2.68554688e-02,
#         2.61718750e-01, -6.22558594e-02, -9.13085938e-02, -5.88378906e-02,
#         6.83593750e-02,  1.41601562e-02, -1.34765625e-01, -1.51367188e-01,
#        -2.46093750e-01,  5.37109375e-03, -7.51953125e-02,  1.22070312e-02,
#         1.00585938e-01,  3.37890625e-01, -8.88671875e-02,  6.93359375e-02,
#        -5.76171875e-02, -2.25585938e-01, -2.24609375e-01, -7.66601562e-02,
#         6.44531250e-02,  2.42919922e-02,  6.73828125e-02,  3.44238281e-02,
#         7.23266602e-03,  9.94873047e-03, -1.34765625e-01, -1.79687500e-01,
#         8.98437500e-02,  1.21582031e-01, -1.17187500e-01,  2.03125000e-01,
#         1.55273438e-01, -4.29687500e-02,  4.51660156e-02,  3.01513672e-02,
#        -3.44238281e-02,  1.89453125e-01, -2.28271484e-02, -1.51367188e-01,
#        -1.24511719e-01, -1.39648438e-01, -8.25195312e-02,  1.58203125e-01,
#        -1.25976562e-01,  2.35595703e-02, -8.78906250e-02, -2.33398438e-01,
#         6.34765625e-03, -3.41796875e-02,  1.21093750e-01,  2.55859375e-01,
#        -1.94335938e-01, -8.78906250e-02,  3.29589844e-03, -1.04003906e-01,
#        -2.29492188e-02,  1.42211914e-02,  1.66992188e-01, -1.30004883e-02,
#        -8.69140625e-02,  1.33789062e-01,  3.10058594e-02,  3.20312500e-01,
#         8.78906250e-03, -1.60156250e-01, -1.22070312e-01,  1.80664062e-01,
#         6.56127930e-03, -6.59179688e-02, -1.23046875e-01,  1.15234375e-01,
#        -1.06445312e-01,  1.52343750e-01,  1.04492188e-01, -1.61132812e-02,
#         7.17773438e-02, -1.63085938e-01, -7.03125000e-02, -4.48608398e-03,
#         5.02929688e-02,  1.03515625e-01,  4.10156250e-02, -3.47137451e-04,
#         8.74023438e-02,  9.76562500e-02, -1.74804688e-01,  1.45874023e-02,
#        -1.03027344e-01,  1.06933594e-01, -1.43554688e-01,  4.63867188e-02,
#         8.25195312e-02,  2.53906250e-01,  1.39648438e-01, -1.34765625e-01,
#         4.98046875e-02,  1.44042969e-02, -2.12402344e-02,  2.34375000e-02,
#        -1.79687500e-01, -1.25976562e-01,  6.78710938e-02,  2.05078125e-01,
#        -2.73437500e-01,  9.37500000e-02,  1.91406250e-01, -2.31445312e-01,
#        -1.69921875e-01,  6.73828125e-02, -2.01171875e-01,  8.74023438e-02,
#        -2.11914062e-01,  6.28662109e-03, -6.88476562e-02, -4.22363281e-02,
#        -3.39355469e-02, -1.29882812e-01,  2.14843750e-02, -6.62231445e-03,
#         2.02148438e-01, -6.68945312e-02,  1.69677734e-02,  2.92968750e-01,
#        -2.27539062e-01, -1.45507812e-01,  1.75781250e-01,  7.08007812e-02,
#         5.73730469e-02, -2.17773438e-01,  1.51367188e-01,  2.74658203e-02,
#         1.85546875e-01,  5.15136719e-02,  1.46484375e-01, -2.53906250e-01,
#        -1.46484375e-02, -6.28662109e-03, -4.85229492e-03,  1.29882812e-01,
#         1.89453125e-01, -3.32031250e-02, -9.81445312e-02,  2.28271484e-02,
#        -6.64062500e-02,  3.97949219e-02, -2.79296875e-01,  6.92749023e-03,
#         1.48437500e-01, -2.26562500e-01,  1.39648438e-01, -1.11328125e-01,
#         2.91015625e-01,  1.88476562e-01, -1.44531250e-01,  1.79687500e-01,
#        -4.07714844e-02,  1.27929688e-01, -2.49023438e-01, -7.12890625e-02,
#        -1.12304688e-01,  1.70898438e-01, -1.55273438e-01,  1.12792969e-01,
#         7.66601562e-02, -3.56445312e-02, -1.83593750e-01, -1.17187500e-01,
#        -6.98242188e-02,  1.90429688e-01, -1.69921875e-01,  1.33666992e-02,
#         2.73437500e-01,  2.44140625e-01,  9.22851562e-02, -1.95312500e-01,
#         1.03515625e-01, -7.12890625e-02, -1.84570312e-01, -1.73339844e-02,
#        -1.14746094e-02,  1.29882812e-01, -4.39453125e-02, -4.68750000e-02,
#         3.39355469e-02,  7.56835938e-02, -4.37011719e-02, -3.75000000e-01,
#         1.94335938e-01, -1.25000000e-01, -1.93359375e-01,  9.66796875e-02,
#         1.87500000e-01, -4.61425781e-02,  2.86865234e-02, -9.17968750e-02,
#        -5.61523438e-02,  1.82617188e-01, -3.95507812e-02,  4.17480469e-02,
#         4.66308594e-02, -1.03515625e-01,  8.30078125e-02, -1.71875000e-01,
#        -1.76757812e-01, -1.09375000e-01, -2.85156250e-01, -2.75390625e-01,
#         1.83593750e-01,  2.08007812e-01,  2.20703125e-01, -4.90722656e-02,
#        -2.01171875e-01, -6.12792969e-02,  2.09960938e-01,  2.17773438e-01,
#         1.09375000e-01,  9.70458984e-03,  1.59912109e-02,  1.23046875e-01,
#         5.29785156e-02, -2.01171875e-01, -1.42578125e-01,  1.39648438e-01,
#         9.47265625e-02,  3.63769531e-02, -6.98242188e-02,  1.25976562e-01,
#         4.07714844e-02,  3.02734375e-02,  5.15136719e-02, -1.94335938e-01,
#         6.00585938e-02, -9.47265625e-02, -2.29492188e-01, -3.69262695e-03,
#        -8.74023438e-02, -1.62109375e-01, -4.22363281e-02, -1.62109375e-01,
#        -1.35742188e-01, -3.14453125e-01, -3.24218750e-01, -2.32421875e-01],
#       dtype=float32)

# %%
similar_words = word2vec_model.most_similar("king", topn=5)
print(similar_words)
# Out:
# [('kings', 0.7138045430183411), ('queen', 0.6510956883430481), ('monarch', 0.6413194537162781), ('crown_prince', 0.6204220056533813), ('prince', 0.6159993410110474)]
